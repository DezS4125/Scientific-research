# %%
from ultralytics import YOLO
import cv2
# import os
# import sendImageToKafkaTopic as si

# %%
# # Load a model
# model = YOLO("yolov8n-face.pt") # load a pretrained model (recommended for training)

# # Use the model
# results = model(frame) # predict on an image
# # Access the first result
# result = results[0]

# %%
model = YOLO('/home/dezs/Projects/Scientific research/testModel/jany.pt')
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, frame = cap.read()
    if not ret:
        break
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model.predict(img)
    for r in results:
        for box in r.boxes.xyxy:
            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        for conf in r.boxes.conf:
            print(conf)
    cv2.imshow('YOLO V8 Detection', frame)
    if cv2.waitKey(1) & 0xFF == ord(' '):
        break

cap.release()
cv2.destroyAllWindows()

# %%
model = YOLO('/home/dezs/Projects/Scientific research/yolov8n-face.pt')
cap = cv2.VideoCapture('/home/dezs/Projects/Scientific research/testModel/jany3.mp4')
# cap.set(3, 640)
# cap.set(4, 480)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model.predict(img)
    for r in results:
        for box in r.boxes.xyxy:
            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        for conf in r.boxes.conf:
            print(conf)
    cv2.imshow('YOLO V8 Detection', frame)
    if cv2.waitKey(1) & 0xFF == ord(' '):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 face, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 1 face, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 7.9ms
# Speed: 3.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 6.4ms
# Speed: 3.8ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 7.2ms
# ...
